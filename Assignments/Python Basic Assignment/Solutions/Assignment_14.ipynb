# %%
1. What does RGBA stand for?
2. From the Pillow module, how do you get the RGBA value of any images?
3. What is a box tuple, and how does it work?
4. Use your image and load in notebook then, How can you find out the width and height of an
Image object?
5. What method would you call to get Image object for a 100×100 image, excluding the lower-left
quarter of it?
6. After making changes to an Image object, how could you save it as an image file?
7. What module contains Pillow’s shape-drawing code?
8. Image objects do not have drawing methods. What kind of object does? How do you get this kind
of object?

# %%
"""
1. What does RGBA stand for?
"""
"""
1.Answer) 

It's used to represent colors.
rgb stands for red, green and blue colors, 
and 'a' is alpha chanel which is used to set transparency

"""

# %%
"""
2. From the Pillow module, how do you get the RGBA value of any images?
"""
"""
2.Answer) 
    Data will be an Imaging Core object containing thousands of tuples of RGBA values.
    Example:(13, 34, 87, 255)
"""
#img1=Image.open(r"F:\Test\Naruto (2).jpg")
#rgba_image=img1.convert('RGBA')
#rgba_data=rgba_image.getdata()

# %%
"""
3. What is a box tuple, and how does it work?
"""
"""
3.Answer)

The box tuple has four integer coordinates that represent a rectangular region in an image.
The four integers are, in order, as follows:

Left: The x-coordinate of the leftmost edge of the box.

Top: The y-coordinate of the top edge of the box.

Right: The x-coordinate of one pixel to the right of the rightmost edge of the box.
        This integer must be greater than the left integer.

Bottom: The y-coordinate of one pixel lower than the bottom edge of the box. 
        This integer must be greater than the top integer.
        
        Eg: (3, 1, 9, 6)
"""

# %%
"""
4. Use your image and load in notebook then, How can you find out the width and height of an
Image object?
"""
"""
4.Answer) Using size attribute of image object
"""
from matplotlib import pyplot as plt
from PIL import Image
# %matplotlib inline
img1=Image.open(r"F:\Test\Kitten.jpg")
plt.imshow(img1)
print(img1.size)
# Out:
# (661, 553)

# %%
"""
5. What method would you call to get Image object for a 100×100 image, excluding the lower-left
quarter of it?
"""
"""
5.Answer) Assuming the question is to get a 100*100 image after excluding the lower-left quarter of it

"""
from PIL import ImageChops,ImageFilter
import numpy as np 
img2=Image.open(r"F:\Test\Kitten.jpg").convert('RGB')
img2_arr=np.array(img2)
img2_arr[276:553,0:331]=(0,0,0)
image=Image.fromarray(img2_arr).resize((100,100))
plt.imshow(image)

# %%
"""
6. After making changes to an Image object, how could you save it as an image file?
"""
"""
6.Answer) using save method of the Image object.
"""
img3.save('F:\Test\cropped.jpg')

# %%
"""
7. What module contains Pillow’s shape-drawing code?
"""
"""
7.Answer) ImageDraw module
from PIL import ImageDraw
"""

# %%
"""
8. Image objects do not have drawing methods. What kind of object does? How do you get this kind
of object?
"""
"""
8.Answer) ImageDraw module has a method Draw which gives us PIL.ImageDraw.ImageDraw object. 

from PIL import ImageDraw
drawObj=ImageDraw.Draw(img3)

"""
